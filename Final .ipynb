# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
from copy import deepcopy
import random
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
from scipy import stats
from sklearn import preprocessing
from kmodes.kprototypes import KPrototypes
from sklearn.cluster import KMeans
#from orion.contrib.envs import load_env
#load_env()
import boto3

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#from orion.sources import S3Source
aws_bucket = 'kilimanjaro-prod-datalake'
s3 = boto3.client('s3')

# %%
cust_summary = cust_summary[['customerkey','orders','total_unitssold','total_grosssales','days_bw_orders','ASP','loyaltyaccount','gender', 'shipcountry','postcode','latitude','longitude' ,'category','divisioncode','productgroup','brandcode']]

# %%
cust_summary = pd.read_csv('cust_summary.csv', index_col=0)

# %%
cust_summary.isnull().sum()
# Out:
# customerkey         0
# orders              0
# total_unitssold     0
# total_grosssales    0
# days_bw_orders      0
# ASP                 0
# loyaltyaccount      0
# gender              0
# shipcountry         0
# postcode            0
# category            0
# divisioncode        0
# productgroup        0
# brandcode           0
# latitude            0
# longitude           0
# dtype: int64

# %%
cont_custsum = cust_summary[['orders','total_unitssold','total_grosssales','days_bw_orders','ASP','latitude','longitude']]

# %%
from io import StringIO  
csv_buffer = StringIO()
cont_custsum.to_csv(csv_buffer)
s3_resource = boto3.resource('s3')
s3_resource.Object('kilimanjaro-prod-datalake','masters/datascience/emma/cont_custsum.csv').put(Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': 'YYWP50AF9Y1K9V29',
#   'HostId': '9Lc6kqXAV+dQfV/ovZsh0ClCPI2r7LCOoU57pXYPPh+Sa4xu57yyj33e/11Y02+6P61LnjK69eo=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '9Lc6kqXAV+dQfV/ovZsh0ClCPI2r7LCOoU57pXYPPh+Sa4xu57yyj33e/11Y02+6P61LnjK69eo=',
#    'x-amz-request-id': 'YYWP50AF9Y1K9V29',
#    'date': 'Mon, 05 Jul 2021 14:09:28 GMT',
#    'x-amz-version-id': 'oDtdqSCP5CNZb8OXnmeJfeiV2xs5eUui',
#    'x-amz-server-side-encryption': 'aws:kms',
#    'x-amz-server-side-encryption-aws-kms-key-id': 'arn:aws:kms:eu-west-1:794236216820:key/68512d48-1991-4929-91a2-1892476cd145',
#    'etag': '"6679f49b96cb9b74eb841454c6e0e880"',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 1},
#  'ETag': '"6679f49b96cb9b74eb841454c6e0e880"',
#  'ServerSideEncryption': 'aws:kms',
#  'VersionId': 'oDtdqSCP5CNZb8OXnmeJfeiV2xs5eUui',
#  'SSEKMSKeyId': 'arn:aws:kms:eu-west-1:794236216820:key/68512d48-1991-4929-91a2-1892476cd145'}

# %%
cust_summary['orders'].describe().round(2)
# Out:
# count    2204873.00
# mean           1.51
# std            1.31
# min            1.00
# 25%            1.00
# 50%            1.00
# 75%            2.00
# max          256.00
# Name: orders, dtype: float64

# %%
cut_labels_4 = ['1', '2-5', '6-20', '20+']
cut_bins = [0, 1, 5, 20, 256]
cust_summary['orders_1'] = pd.cut(cust_summary['orders'], bins=cut_bins, labels=cut_labels_4)

# %%
cust_summary.head()
# Out:
#                                 customerkey  orders  total_unitssold  \
# 0  fb484d6a54da0d56910e2df0064c18c722801a66     256              603
# 1  649cca818138ed8152825855e0538ed7360bd55a     152              400
# 2  559aec727d6d73e55e476a34a374f1fb26dc06cf     152              401
# 3  35d17f77612459a698d0179b7525c6eedacc6fd6     144              469
# 4  67f9aeeef82eefa706b6886df0b790992e3b5a61     114              225
#
#    total_grosssales  days_bw_orders    ASP loyaltyaccount  gender  \
# 0          35645.08               4  61.44            Yes  female
# 1          18320.26               9  51.97            Yes  female
# 2          16730.55               7  44.44            Yes  female
# 3          15046.12               8  37.51            Yes  female
# 4          11631.89              11  63.97            Yes    male
#
#       shipcountry postcode category divisioncode   productgroup brandcode  \
# 0  United Kingdom      TW9   Junior     FOOTWEAR     Basketball        AA
# 1  United Kingdom      DL5     Mens      APPAREL  Nylon Running        NN
# 2  United Kingdom     LL18     Mens     FOOTWEAR     Vulcanised        NN
# 3  United Kingdom      N19     Mens      APPAREL       T-shirts       KWD
# 4  United Kingdom      WA1   Womens     FOOTWEAR  Nylon Running        AA
#
#    latitude  longitude orders_1
# 0   51.4728  -0.296367      20+
# 1   54.6000  -1.587800      20+
# 2   53.2910  -3.454820      20+
# 3   51.5649  -0.135100      20+
# 4   53.3925  -2.561000      20+

# %%
pd.cut(cust_summary['orders'], bins=6).value_counts()
# Out:
# (0.745, 43.5]     2204833
# (43.5, 86.0]           27
# (86.0, 128.5]           9
# (128.5, 171.0]          3
# (213.5, 256.0]          1
# (171.0, 213.5]          0
# Name: orders, dtype: int64

# %%
cust_summary['total_unitssold'].describe().round(2)
# Out:
# count    2204873.00
# mean           4.98
# std            6.34
# min           -1.00
# 25%            2.00
# 50%            4.00
# 75%            6.00
# max          603.00
# Name: total_unitssold, dtype: float64

# %%
cust_summary['total_grosssales'].describe().round(2)
# Out:
# count    2204873.00
# mean         193.04
# std          238.96
# min            0.22
# 25%           75.41
# 50%          126.99
# 75%          218.37
# max        35645.08
# Name: total_grosssales, dtype: float64

# %%
cust_summary['days_bw_orders'].describe().round(2)
# Out:
# count    2204873.00
# mean        1407.43
# std          709.78
# min            1.00
# 25%          744.00
# 50%         1825.00
# 75%         1825.00
# max         1825.00
# Name: days_bw_orders, dtype: float64

# %%
cust_summary['ASP'].describe().round(2)
# Out:
# count    2204873.00
# mean          46.15
# std           27.36
# min            0.22
# 25%           25.91
# 50%           37.42
# 75%           61.44
# max          286.68
# Name: ASP, dtype: float64

# %%
cust_summary['latitude'].describe().round(2)
# Out:
# count    2125392.00
# mean          52.76
# std            1.48
# min           49.19
# 25%           51.54
# 50%           52.48
# 75%           53.56
# max           60.68
# Name: latitude, dtype: float64

# %%
cust_summary['longitude'].describe().round(2)
# Out:
# count    2125392.00
# mean          -1.64
# std            1.49
# min           -7.86
# 25%           -2.56
# 50%           -1.55
# 75%           -0.34
# max            1.72
# Name: longitude, dtype: float64

# %%
cust_categories = cust_summary[['loyaltyaccount','gender','shipcountry','category','divisioncode']]

# %%
from io import StringIO  
csv_buffer = StringIO()
cust_summary.to_csv(csv_buffer)
s3_resource = boto3.resource('s3')
s3_resource.Object('kilimanjaro-prod-datalake','masters/datascience/emma/cust_summary.csv').put(Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': 'K3T2D46GYZV8BEH5',
#   'HostId': 'yY0u3mePQXcX54LcEfUk+mA3aVsmYLpoMcAdeDA3JC/Hu01z88UewTFqfdnIRYPrM7gM5qOOwC0=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'yY0u3mePQXcX54LcEfUk+mA3aVsmYLpoMcAdeDA3JC/Hu01z88UewTFqfdnIRYPrM7gM5qOOwC0=',
#    'x-amz-request-id': 'K3T2D46GYZV8BEH5',
#    'date': 'Mon, 05 Jul 2021 10:20:55 GMT',
#    'x-amz-version-id': 'enq2DtHPDBsBHiwg_SNZvz5erO4ybVQe',
#    'x-amz-server-side-encryption': 'aws:kms',
#    'x-amz-server-side-encryption-aws-kms-key-id': 'arn:aws:kms:eu-west-1:794236216820:key/68512d48-1991-4929-91a2-1892476cd145',
#    'etag': '"cc09b9b2ab3a8d57dda0250f871fdc1a"',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 1},
#  'ETag': '"cc09b9b2ab3a8d57dda0250f871fdc1a"',
#  'ServerSideEncryption': 'aws:kms',
#  'VersionId': 'enq2DtHPDBsBHiwg_SNZvz5erO4ybVQe',
#  'SSEKMSKeyId': 'arn:aws:kms:eu-west-1:794236216820:key/68512d48-1991-4929-91a2-1892476cd145'}

# %%
cust_summary.head()
# Out:
#                                 customerkey  orders  total_unitssold  \
# 0  fb484d6a54da0d56910e2df0064c18c722801a66     256              603
# 1  649cca818138ed8152825855e0538ed7360bd55a     152              400
# 2  559aec727d6d73e55e476a34a374f1fb26dc06cf     152              401
# 3  35d17f77612459a698d0179b7525c6eedacc6fd6     144              469
# 4  67f9aeeef82eefa706b6886df0b790992e3b5a61     114              225
#
#    total_grosssales  days_bw_orders    ASP loyaltyaccount  gender  \
# 0          35645.08               4  61.44            Yes  female
# 1          18320.26               9  51.97            Yes  female
# 2          16730.55               7  44.44            Yes  female
# 3          15046.12               8  37.51            Yes  female
# 4          11631.89              11  63.97            Yes    male
#
#       shipcountry postcode  latitude  longitude category divisioncode  \
# 0  United Kingdom      TW9   51.4728  -0.296367   Junior     FOOTWEAR
# 1  United Kingdom      DL5   54.6000  -1.587800     Mens      APPAREL
# 2  United Kingdom     LL18   53.2910  -3.454820     Mens     FOOTWEAR
# 3  United Kingdom      N19   51.5649  -0.135100     Mens      APPAREL
# 4  United Kingdom      WA1   53.3925  -2.561000   Womens     FOOTWEAR
#
#     productgroup brandcode
# 0     Basketball        AA
# 1  Nylon Running        NN
# 2     Vulcanised        NN
# 3       T-shirts       KWD
# 4  Nylon Running        AA

# %%
sample = cust_summary.sample(n= 1000)

# %%
sample = sample[['orders','total_unitssold','total_grosssales', 'ASP','loyaltyaccount','gender','category','divisioncode']]

# %%
cust_norm = sample.copy()
scaler = preprocessing.MinMaxScaler()
cust_norm[['orders','total_unitssold','total_grosssales','ASP']] = scaler.fit_transform(cust_norm[['orders','total_unitssold','total_grosssales','ASP']])

# %%
kproto = KPrototypes(n_clusters=3, init='Cao')
clusters = kproto.fit_predict(cust_norm, categorical=[4,5,6,7])

# %%
sample['cluster']= clusters

# %%
sample.sort_values("total_grosssales", ascending=False, inplace = True)
sample
# Out:
#          orders  total_unitssold  total_grosssales    ASP loyaltyaccount  \
# 40485         6               58           4265.45  77.86            Yes
# 5250         12               52           2411.70  49.87            Yes
# 1841         16               72           2376.86  34.04            Yes
# 27470         7               70           1778.54  27.14            Yes
# 31906         7               38           1273.87  51.18            Yes
# ...         ...              ...               ...    ...            ...
# 2808392       1                2             24.21  12.10             No
# 2757907       1                2             24.00  12.00             No
# 2584304       1                2             23.41  11.70            Yes
# 1580927       1                2             21.19  10.60             No
# 2045543       1                2             19.23   9.62             No
#
#          gender       category divisioncode  cluster
# 40485      male           Mens     FOOTWEAR        1
# 5250       male           Mens      APPAREL        1
# 1841     female           Mens     FOOTWEAR        1
# 27470      male           Mens      APPAREL        1
# 31906    female           Mens      APPAREL        1
# ...         ...            ...          ...      ...
# 2808392  female  Miscellaneous    ACCESSORY        0
# 2757907  female         Womens      APPAREL        0
# 2584304    male           Mens      APPAREL        1
# 1580927    male           Mens    ACCESSORY        0
# 2045543  female           Mens      APPAREL        0
#
# [1000 rows x 9 columns]

# %%
cust_norm = pd.get_dummies(cust_norm, columns=['loyaltyaccount','gender','category','divisioncode'])

# %%
cust_norm
# Out:
#            orders  total_unitssold  total_grosssales       ASP  \
# 2029254  0.000000         0.070423          0.082827  0.240144
# 1807427  0.000000         0.042254          0.027179  0.110595
# 2748836  0.000000         0.000000          0.015786  0.352579
# 2434295  0.000000         0.000000          0.009159  0.223122
# 1807948  0.000000         0.042254          0.022462  0.087547
# ...           ...              ...               ...       ...
# 670404   0.066667         0.028169          0.032992  0.247044
# 2796532  0.000000         0.014085          0.037735  0.368542
# 1392769  0.000000         0.014085          0.005732  0.055987
# 1257340  0.000000         0.000000          0.033783  0.704145
# 966364   0.000000         0.014085          0.011580  0.113079
#
#          loyaltyaccount_No  loyaltyaccount_Yes  gender_female  gender_male  \
# 2029254                  0                   1              0            1
# 1807427                  0                   1              0            1
# 2748836                  0                   1              1            0
# 2434295                  0                   1              0            0
# 1807948                  0                   1              1            0
# ...                    ...                 ...            ...          ...
# 670404                   0                   1              1            0
# 2796532                  1                   0              0            0
# 1392769                  1                   0              1            0
# 1257340                  1                   0              0            1
# 966364                   1                   0              1            0
#
#          gender_unknown  category_Boys  category_Childrens  category_Infant  \
# 2029254               0              0                   0                0
# 1807427               0              0                   0                0
# 2748836               0              0                   0                0
# 2434295               1              0                   0                0
# 1807948               0              0                   0                0
# ...                 ...            ...                 ...              ...
# 670404                0              0                   0                0
# 2796532               1              0                   0                0
# 1392769               0              0                   0                0
# 1257340               0              0                   0                0
# 966364                0              0                   0                0
#
#          category_Junior  category_Mens  category_Miscellaneous  \
# 2029254                0              1                       0
# 1807427                0              1                       0
# 2748836                0              1                       0
# 2434295                0              0                       0
# 1807948                0              0                       1
# ...                  ...            ...                     ...
# 670404                 1              0                       0
# 2796532                0              0                       0
# 1392769                0              0                       0
# 1257340                0              1                       0
# 966364                 0              0                       1
#
#          category_Nursery  category_Womens  divisioncode_ACCESSORY  \
# 2029254                 0                0                       0
# 1807427                 0                0                       0
# 2748836                 0                0                       0
# 2434295                 0                1                       0
# 1807948                 0                0                       1
# ...                   ...              ...                     ...
# 670404                  0                0                       0
# 2796532                 0                1                       0
# 1392769                 0                1                       0
# 1257340                 0                0                       0
# 966364                  0                0                       1
#
#          divisioncode_APPAREL  divisioncode_FOOTWEAR
# 2029254                     1                      0
# 1807427                     0                      1
# 2748836                     0                      1
# 2434295                     0                      1
# 1807948                     0                      0
# ...                       ...                    ...
# 670404                      0                      1
# 2796532                     0                      1
# 1392769                     1                      0
# 1257340                     0                      1
# 966364                      0                      0
#
# [1000 rows x 20 columns]

# %%
kmeans = KMeans(3)
clusters = kmeans.fit_predict(cust_norm)
labels = pd.DataFrame(clusters)

# %%
sample['cluster']= labels

# %%
sample.head()
# Out:
#                                       customerkey  orders  total_unitssold  \
# 954316   e2d1b8ba0cfd57a18fd605a32bbf3d48bd0fd97d       1                2
# 1612722  0522f75e0702371361bd59176b8b68fa6dc47e27       1                2
# 1449780  3a75b4f2fd17e44a4066c92540e1e831bf4cb4d5       1                2
# 1652866  23752b002fed8c4d8f630f4e114a2b1007bde027       1                9
# 739645   fb6dc85351a4512e3e670e897cdf297b78c43327       1                4
#
#          total_grosssales  days_bw_orders    ASP loyaltyaccount   gender  \
# 954316              57.18            1825  28.59            Yes   female
# 1612722             67.32            1825  33.66             No  unknown
# 1449780             50.05            1825  25.02            Yes     male
# 1652866            307.58            1825  34.18            Yes     male
# 739645             137.80            1825  34.45             No   female
#
#             shipcountry postcode       category divisioncode  \
# 954316   United Kingdom     WS15         Junior     FOOTWEAR
# 1612722  United Kingdom     RG42  Miscellaneous    ACCESSORY
# 1449780  United Kingdom      B67           Mens      APPAREL
# 1652866  United Kingdom     HP20           Mens      APPAREL
# 739645   United Kingdom     TS57           Mens      APPAREL
#
#              productgroup brandcode  cluster
# 954316         Basketball        NN      NaN
# 1612722  Non-retail items      none      NaN
# 1449780  Non-retail items       KWD      NaN
# 1652866          Knitwear       BRA      NaN
# 739645           T-shirts       NIC      NaN

# %%
cust_summary.head(2)
# Out:
#                                 customerkey  orders  total_unitssold  \
# 0  fb484d6a54da0d56910e2df0064c18c722801a66     256              603
# 1  649cca818138ed8152825855e0538ed7360bd55a     152              400
#
#    total_grosssales  days_bw_orders    ASP loyaltyaccount  gender  \
# 0          35645.08               4  61.44            Yes  female
# 1          18320.26               9  51.97            Yes  female
#
#       shipcountry postcode category divisioncode   productgroup brandcode
# 0  United Kingdom      TW9   Junior     FOOTWEAR     Basketball        AA
# 1  United Kingdom      DL5     Mens      APPAREL  Nylon Running        NN

# %%
def class_(row):
    if row['orders'] > 1:
        val = 1
    else: 
        val = 0
    return val

# %%
cust_summary['class'] = cust_summary.apply(class_, axis=1)

# %%
cust_summary.head(2)
# Out:
#                                 customerkey  orders  total_unitssold  \
# 0  fb484d6a54da0d56910e2df0064c18c722801a66     256              603
# 1  649cca818138ed8152825855e0538ed7360bd55a     152              400
#
#    total_grosssales  days_bw_orders    ASP loyaltyaccount  gender  \
# 0          35645.08               4  61.44            Yes  female
# 1          18320.26               9  51.97            Yes  female
#
#       shipcountry postcode category divisioncode   productgroup brandcode  \
# 0  United Kingdom      TW9   Junior     FOOTWEAR     Basketball        AA
# 1  United Kingdom      DL5     Mens      APPAREL  Nylon Running        NN
#
#    class
# 0      1
# 1      1

# %%
full = pd.read_csv('Product_customer.csv', index_col=0)
full.head(1)
# Out:
#                                 customerkey  itemnumber  unitssold brandcode  \
# 0  0000010177de5b4048370276b036ff3ba06b7ae6      116075          2        NN
#
#   category divisioncode   productgroup  orders  total_grosssales  total_items  \
# 0   Junior     FOOTWEAR  Nylon Running       1            135.51            1
#
#    total_unitssold    ASP loyaltyaccount  gender
# 0                4  33.88             No  female
